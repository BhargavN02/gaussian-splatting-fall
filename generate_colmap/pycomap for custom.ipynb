# %%
import pycolmap
import os
import numpy as np

def read_calibration_matrix(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        K = []
        for line in lines:
            if line.startswith('K'):
                line = line.split('=')[1].strip().strip('[]')
                line = line.replace(';', '')  # Remove semicolons
                K.extend([float(x) for x in line.split()])
        # Handle multi-line matrix
        for line in lines:
            if not line.startswith('K') and line.strip():
                line = line.strip().strip('[]')
                line = line.replace(';', '')  # Remove semicolons
                K.extend([float(x) for x in line.split()])
    return np.array(K).reshape(3, 3)

#this is the path to the images
image_path = '/Users/bhargavsrisainama/Documents/personal/Research/SfMDataset/images'
#this is the database file created that will be used to store the features and matches
database_path = '/Users/bhargavsrisainama/Documents/personal/Research/SfMDataset/database.db' 
#this is the path where the sparse reconstruction will be stored
sparse_path = '/Users/bhargavsrisainama/Documents/personal/Research/sfm/sparse'
#this is the path to the calibration file generated from sfm
calibration_path = '/Users/bhargavsrisainama/Documents/personal/Research/SfMDataset/calibration.txt'

# Read the calibration matrix
K = read_calibration_matrix(calibration_path)
fx, fy = float(K[0, 0]), float(K[1, 1])
cx, cy = float(K[0, 2]), float(K[1, 2])

# Create ImageReaderOptions with camera parameters
reader_options = pycolmap.ImageReaderOptions()
reader_options.camera_model = 'PINHOLE'
reader_options.camera_params = f"{fx},{fy},{cx},{cy}"  # Convert to comma-separated string

# Feature extraction
pycolmap.extract_features(
    database_path=database_path,
    image_path=image_path,
    reader_options=reader_options
)

# Exhaustive matching
pycolmap.match_exhaustive(database_path=database_path)

# Create sparse reconstruction directory
os.makedirs(sparse_path, exist_ok=True)

# Run the incremental mapping
maps = pycolmap.incremental_mapping(
    database_path=database_path,
    image_path=image_path,
    output_path=sparse_path
)

# Save the reconstruction from the first model (folder `0`)
maps[0].write(os.path.join(sparse_path, '0'))
# Out:
# W20241111 13:54:53.230570 0x1f1def840 feature_extraction.cc:406] Your current options use the maximum number of threads on the machine to extract features. Extracting SIFT features on the CPU can consume a lot of RAM per thread for large images. Consider reducing the maximum image size and/or the first octave or manually limit the number of extraction threads. Ignore this warning, if your machine has sufficient memory for the current settings.
# I20241111 13:54:53.230985 0x1717e3000 misc.cc:198]
# ==============================================================================
# Feature extraction
# ==============================================================================
# I20241111 13:54:53.231415 0x171d5b000 sift.cc:722] Creating SIFT CPU feature extractor
# I20241111 13:54:53.231424 0x171de7000 sift.cc:722] Creating SIFT CPU feature extractor
# I20241111 13:54:53.231428 0x171e73000 sift.cc:722] Creating SIFT CPU feature extractor
# I20241111 13:54:53.231433 0x171eff000 sift.cc:722] Creating SIFT CPU feature extractor
# I20241111 13:54:53.231443 0x171f8b000 sift.cc:722] Creating SIFT CPU feature extractor
# I20241111 13:54:53.231461 0x172017000 sift.cc:722] Creating SIFT CPU feature extractor
# I20241111 13:54:53.231454 0x171ccf000 sift.cc:722] Creating SIFT CPU feature extractor
# I20241111 13:54:53.231488 0x1720a3000 sift.cc:722] Creating SIFT CPU feature extractor
# I20241111 13:54:53.232041 0x17212f000 feature_extraction.cc:257] Processed file [1/6]
# I20241111 13:54:53.232049 0x17212f000 feature_extraction.cc:260]   Name:            1.jpg
# I20241111 13:54:53.232051 0x17212f000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20241111 13:54:53.232323 0x17212f000 feature_extraction.cc:257] Processed file [2/6]
# I20241111 13:54:53.232355 0x17212f000 feature_extraction.cc:260]   Name:            2.jpg
# I20241111 13:54:53.232361 0x17212f000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20241111 13:54:53.232447 0x17212f000 feature_extraction.cc:257] Processed file [3/6]
# I20241111 13:54:53.232479 0x17212f000 feature_extraction.cc:260]   Name:            3.jpg
# I20241111 13:54:53.232493 0x17212f000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20241111 13:54:53.232620 0x17212f000 feature_extraction.cc:257] Processed file [4/6]
# I20241111 13:54:53.232625 0x17212f000 feature_extraction.cc:260]   Name:            4.jpg
# I20241111 13:54:53.232627 0x17212f000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20241111 13:54:53.232729 0x17212f000 feature_extraction.cc:257] Processed file [5/6]
# I20241111 13:54:53.232762 0x17212f000 feature_extraction.cc:260]   Name:            5.jpg
# I20241111 13:54:53.232769 0x17212f000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20241111 13:54:53.232773 0x17212f000 feature_extraction.cc:257] Processed file [6/6]
# I20241111 13:54:53.232777 0x17212f000 feature_extraction.cc:260]   Name:            6.jpg
# I20241111 13:54:53.232781 0x17212f000 feature_extraction.cc:264]   SKIP: Features for image already extracted.
# I20241111 13:54:53.233628 0x1717e3000 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20241111 13:54:53.237020 0x1717e3000 misc.cc:198]
# ==============================================================================
# Feature matching
# ==============================================================================
# I20241111 13:54:53.237745 0x17186f000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20241111 13:54:53.237823 0x171a13000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20241111 13:54:53.237749 0x171987000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20241111 13:54:53.237867 0x171c43000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20241111 13:54:53.237753 0x1718fb000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20241111 13:54:53.237787 0x171a9f000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20241111 13:54:53.237823 0x171b2b000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20241111 13:54:53.237836 0x171bb7000 sift.cc:1457] Creating SIFT CPU feature matcher
# I20241111 13:54:53.238189 0x1717e3000 pairing.cc:168] Generating exhaustive image pairs...
# I20241111 13:54:53.238196 0x1717e3000 pairing.cc:202] Matching block [1/1, 1/1]
# I20241111 13:54:53.240852 0x1717e3000 feature_matching.cc:46]  in 0.003s
# I20241111 13:54:53.240864 0x1717e3000 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20241111 13:54:53.241432 0x1f1def840 incremental_mapper.cc:225] Loading database
# I20241111 13:54:53.242645 0x1f1def840 database_cache.cc:65] Loading cameras...
# I20241111 13:54:53.242670 0x1f1def840 database_cache.cc:75]  12 in 0.000s
# I20241111 13:54:53.242674 0x1f1def840 database_cache.cc:83] Loading matches...
# I20241111 13:54:53.243118 0x1f1def840 database_cache.cc:89]  53 in 0.000s
# I20241111 13:54:53.243122 0x1f1def840 database_cache.cc:105] Loading images...
# I20241111 13:54:53.254343 0x1f1def840 database_cache.cc:155]  12 in 0.011s (connected 12)
# I20241111 13:54:53.254352 0x1f1def840 database_cache.cc:166] Building correspondence graph...
# I20241111 13:54:53.259120 0x1f1def840 database_cache.cc:195]  in 0.005s (ignored 0)
# I20241111 13:54:53.259135 0x1f1def840 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20241111 13:54:53.259923 0x1f1def840 incremental_mapper.cc:265] Finding good initial image pair
# I20241111 13:54:53.305930 0x1f1def840 incremental_mapper.cc:289] Initializing with image pair #3 and #2
# I20241111 13:54:53.309606 0x1f1def840 incremental_mapper.cc:294] Global bundle adjustment
# I20241111 13:54:53.796585 0x1f1def840 incremental_mapper.cc:375] Registering image #4 (3)
# I20241111 13:54:53.796601 0x1f1def840 incremental_mapper.cc:378] => Image sees 1251 / 4908 points
# I20241111 13:54:54.148261 0x1f1def840 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241111 13:54:55.446188 0x1f1def840 incremental_mapper.cc:375] Registering image #1 (4)
# I20241111 13:54:55.446220 0x1f1def840 incremental_mapper.cc:378] => Image sees 1450 / 3080 points
# I20241111 13:54:55.938233 0x1f1def840 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241111 13:54:56.037645 0x1f1def840 incremental_mapper.cc:375] Registering image #6 (5)
# I20241111 13:54:56.037659 0x1f1def840 incremental_mapper.cc:378] => Image sees 1135 / 4301 points
# I20241111 13:54:56.679801 0x1f1def840 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241111 13:54:57.606858 0x1f1def840 incremental_mapper.cc:375] Registering image #5 (6)
# I20241111 13:54:57.606872 0x1f1def840 incremental_mapper.cc:378] => Image sees 1312 / 3172 points
# I20241111 13:54:58.410494 0x1f1def840 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241111 13:54:58.577517 0x1f1def840 incremental_mapper.cc:375] Registering image #9 (7)
# I20241111 13:54:58.577531 0x1f1def840 incremental_mapper.cc:378] => Image sees 129 / 2934 points
# I20241111 13:54:58.782289 0x1f1def840 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# W20241111 13:54:59.008224 0x1f1def840 incremental_mapper.cc:54] Could not read image images/3.jpg at path /Users/bhargavsrisainama/Documents/personal/Research/SfMDataset/images.
# I20241111 13:54:59.008375 0x1f1def840 incremental_mapper.cc:375] Registering image #11 (8)
# I20241111 13:54:59.008381 0x1f1def840 incremental_mapper.cc:378] => Image sees 130 / 2471 points
# I20241111 13:54:59.255819 0x1f1def840 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# W20241111 13:54:59.675637 0x1f1def840 incremental_mapper.cc:54] Could not read image images/5.jpg at path /Users/bhargavsrisainama/Documents/personal/Research/SfMDataset/images.
# I20241111 13:54:59.675707 0x1f1def840 incremental_mapper.cc:375] Registering image #10 (9)
# I20241111 13:54:59.675711 0x1f1def840 incremental_mapper.cc:378] => Image sees 443 / 2893 points
# I20241111 13:54:59.947158 0x1f1def840 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# W20241111 13:55:00.366624 0x1f1def840 incremental_mapper.cc:54] Could not read image images/4.jpg at path /Users/bhargavsrisainama/Documents/personal/Research/SfMDataset/images.
# I20241111 13:55:00.366676 0x1f1def840 incremental_mapper.cc:375] Registering image #8 (10)
# I20241111 13:55:00.366680 0x1f1def840 incremental_mapper.cc:378] => Image sees 742 / 2632 points
# I20241111 13:55:00.685888 0x1f1def840 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# W20241111 13:55:02.539636 0x1f1def840 incremental_mapper.cc:54] Could not read image images/2.jpg at path /Users/bhargavsrisainama/Documents/personal/Research/SfMDataset/images.
# I20241111 13:55:02.539691 0x1f1def840 incremental_mapper.cc:375] Registering image #7 (11)
# I20241111 13:55:02.540407 0x1f1def840 incremental_mapper.cc:378] => Image sees 709 / 1898 points
# I20241111 13:55:02.861670 0x1f1def840 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# W20241111 13:55:04.042883 0x1f1def840 incremental_mapper.cc:54] Could not read image images/1.jpg at path /Users/bhargavsrisainama/Documents/personal/Research/SfMDataset/images.
# I20241111 13:55:04.042940 0x1f1def840 incremental_mapper.cc:375] Registering image #12 (12)
# I20241111 13:55:04.042944 0x1f1def840 incremental_mapper.cc:378] => Image sees 645 / 1624 points
# W20241111 13:55:04.235506 0x1f1def840 incremental_mapper.cc:54] Could not read image images/6.jpg at path /Users/bhargavsrisainama/Documents/personal/Research/SfMDataset/images.
# I20241111 13:55:04.236282 0x1f1def840 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241111 13:55:04.978795 0x1f1def840 timer.cc:91] Elapsed time: 0.196 [minutes]
